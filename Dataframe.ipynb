# %%
import pandas as pd
import math

# %%
df = pd.read_csv('CATS_DOGS.csv')

# %%
df
# Out:
#         FileName        X1        X2        X3        X4        X5        X6  \
# 0      cat.6.jpg  0.031452  0.020387  0.002684  0.000000  0.000000  0.000000
# 1    dog.211.jpg  0.199146  0.011388  0.000000  0.000000  0.000000  0.000000
# 2    dog.205.jpg  0.005641  0.000118  0.000000  0.000000  0.000000  0.000000
# 3    dog.239.jpg  0.391663  0.185664  0.060114  0.068186  0.121004  0.056145
# 4    cat.239.jpg  0.377214  0.098189  0.003832  0.000724  0.000272  0.000121
# ..           ...       ...       ...       ...       ...       ...       ...
# 995  cat.220.jpg  0.180666  0.053046  0.000788  0.000000  0.000000  0.000000
# 996  cat.234.jpg  0.310841  0.093633  0.000373  0.000000  0.000000  0.000000
# 997  dog.220.jpg  0.226303  0.088692  0.008469  0.010400  0.002202  0.000779
# 998  dog.234.jpg  0.225929  0.000826  0.000000  0.000000  0.000000  0.000000
# 999  dog.208.jpg  0.003642  0.000000  0.000000  0.000000  0.000000  0.000000
#
# ...

# %%
df.Label.loc[df.loc[:,'Label'] == 'cat'] = 1
df.Label.loc[df.loc[:,'Label'] == 'dog'] = 0
df
# Out:
#         FileName        X1        X2        X3        X4        X5        X6  \
# 0              1  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 1    dog.211.jpg  0.199146  0.011388  0.000000  0.000000  0.000000  0.000000
# 2    dog.205.jpg  0.005641  0.000118  0.000000  0.000000  0.000000  0.000000
# 3    dog.239.jpg  0.391663  0.185664  0.060114  0.068186  0.121004  0.056145
# 4              1  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# ..           ...       ...       ...       ...       ...       ...       ...
# 995            1  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 996            1  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 997  dog.220.jpg  0.226303  0.088692  0.008469  0.010400  0.002202  0.000779
# 998  dog.234.jpg  0.225929  0.000826  0.000000  0.000000  0.000000  0.000000
# 999  dog.208.jpg  0.003642  0.000000  0.000000  0.000000  0.000000  0.000000
#
# ...

# %%
df.to_csv('CATS_DOGS_2.csv')
